# %% [markdown]
# # 1. Goal of the Project
# The goal of this project is to show how a music artist (Quadeca) has grown on Spotify since his career began in 2015. I will then try to find events in his career that could have lead to a spike in streams.
#
# The question being asked is "What does growth look like?"

# %% [markdown]
# # 2. The Process

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
streams = pd.read_csv('Streams_Index.csv')
streams
# Out:
#             date  streams_index
# 0     2015-06-02       0.000015
# 1     2015-06-03       0.000022
# 2     2015-06-04       0.000032
# 3     2015-06-05       0.000025
# 4     2015-06-06       0.000029
# ...          ...            ...
# 2145  2021-04-16       0.273343
# 2146  2021-04-17       0.261236
# 2147  2021-04-18       0.239378
# 2148  2021-04-19       0.256178
# 2149  2021-04-20       0.255410
#
# [2150 rows x 2 columns]

# %% [markdown]
# # 3. The Graph
# The data shown takes place between the days of June 2nd, 2015 and April 20th, 2021 (2,150 days).
# The 1.0 represents the day Quadeca got the most streams.

# %%
streams.plot(y='streams_index', x='date')
plt.rcParams["figure.figsize"] = (20,12)

# %% [markdown]
# # 4. Analyzing the Graph
# * Quadeca's most streamed day was on March 31st, 2021. The reason that he had a spike in streams that day is because his album, titled "From Me To You", was released the night before.
# * Quadeca's second largest spike happened on March 14th, 2019. That was six (6) days after his "breakthrough" album, titled "Voice Memos", was released.
# * In late-2018, Quadeca started getting more streams due to exposure from a YouTuber and rapper named KSI.
# * Quadeca's streams in 2020 were very up and down for two main reasons: 1. He had released three songs (causing the rise in streams, because there is new music), 2. He was took a roughly five-month hiatus from social media and YouTube (causing the decline in streams, because there was no new content).

# %% [markdown]
# # 5. Limitations
# Unfortunately, I couldn't get all of the dates to show up on the graph (I think there may have been a limit due to there being over 2,000 entries).
# Also, the data file didn't show the actual amount of streams, and instead did more "ranking" system (1.000 being the highest amount of streams, and 0.00000 being the lowest amount of streams).
